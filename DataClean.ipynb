# %%
import csv
import sys
import os
import pandas as pd
import numpy as np

pathboston="C:/Users/singh/Desktop/AIRBNB DATA/BOSTON/listings.csv"
pathseattle="C:/Users/singh/Desktop/AIRBNB DATA/Seattle/listings_seattle.csv"
pathdc="C:/Users/singh/Desktop/AIRBNB DATA/DC/listings_dc.csv"

boston_df = pd.read_csv(pathboston)
seattle_df = pd.read_csv(pathseattle)
dc_df = pd.read_csv(pathdc)
print(dc_df.shape)
print(seattle_df.shape)
print(boston_df.shape)


# boston_df = boston_df.drop(['access', 'interaction', 'house_rules'], axis=1)
# dc_df = dc_df.drop(['access', 'interaction', 'house_rules'], axis=1)
#same number columns
print("after deleting columns")
print(dc_df.shape)
print(seattle_df.shape)
print(boston_df.shape)
#f = pd.merge(left=dc_df, right=seattle_df, how='outer', on='id')
# Out:
# (7788, 95)
# (3818, 92)
# (3585, 95)
# after deleting columns
# (7788, 95)
# (3818, 92)
# (3585, 95)

# %%
#merge CSV

# %%
df_new = pd.concat([boston_df, dc_df,seattle_df])
df_new.shape
df_new.to_csv("Rawfinal.csv", index=None)
print("rawfile saved")

# %%
print(df_new.head(5))
#list(df_new)
df_new1= df_new[['id',
 'picture_url',
 'xl_picture_url',
 'host_id',
 'host_name',
 'host_response_rate',
 'host_acceptance_rate',
 'host_total_listings_count',
 'neighbourhood_cleansed',
 'city',
 'state',
 'zipcode',
 'country',
 'latitude',
 'longitude',
 'property_type',
 'room_type',
 'accommodates',
 'bathrooms',
 'beds',
 'amenities',
 'price',
   'cancellation_policy',              
 'weekly_price',
 'monthly_price',
 'security_deposit',
 'cleaning_fee',
 'number_of_reviews',
 'review_scores_rating',
 'instant_bookable',
 'reviews_per_month']]
print(df_new1.head(5))
# Out:
#                                               access  accommodates  \
# 0  You will have access to 2 bedrooms, a living r...             4
# 1  Apt has one more bedroom (which I use) and lar...             2
# 2  I am living in the apartment during your stay,...             2
# 3  The basement has a washer dryer and gym area. ...             4
# 4  You will have access to the front and side por...             2
#
#                                            amenities  availability_30  \
# 0  {TV,"Wireless Internet",Kitchen,"Free Parking ...                0
# 1  {TV,Internet,"Wireless Internet","Air Conditio...               26
# 2  {TV,"Cable TV","Wireless Internet","Air Condit...               19
# 3  {TV,Internet,"Wireless Internet","Air Conditio...                6
# 4  {Internet,"Wireless Internet","Air Conditionin...               13
#
#    availability_365  availability_60  availability_90  bathrooms  bed_type  \
# 0                 0                0                0        1.5  Real Bed
# 1               359               54               84        1.0  Real Bed
# 2               319               46               61        1.0  Real Bed
# 3                98               16               26        1.0  Real Bed
# 4               334               34               59        1.5  Real Bed
#
#    bedrooms   ...                                                space  \
# 0       2.0   ...    The house has an open and cozy feel at the sam...
# 1       1.0   ...    Small but cozy and quite room with a full size...
# 2       1.0   ...    Come stay with a friendly, middle-aged guy in ...
# 3       1.0   ...    Most places you find in Boston are small howev...
# 4       1.0   ...    Clean, attractive, private room, one block fro...
#
#    square_feet state                                             street  \
# 0          NaN    MA      Birch Street, Boston, MA 02131, United States
# 1          NaN    MA  Pinehurst Street, Boston, MA 02131, United States
# 2          NaN    MA        Ardale St., Boston, MA 02131, United States
# 3          NaN    MA                          Boston, MA, United States
# 4          NaN    MA    Durnell Avenue, Boston, MA 02131, United States
#
#                                              summary  \
# 0  Cozy, sunny, family home.  Master bedroom high...
# 1  Charming and quiet room in a second floor 1910...
# 2  Come stay with a friendly, middle-aged guy in ...
# 3  Come experience the comforts of home away from...
# 4  My comfy, clean and relaxing home is one block...
#
#                                        thumbnail_url  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1  https://a1.muscache.com/im/pictures/39327812/d...
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3  https://a2.muscache.com/im/pictures/39764190-1...
# 4  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                              transit weekly_price  \
# 0  The bus stop is 2 blocks away, and frequent. B...          NaN
# 1  Plenty of safe street parking. Bus stops a few...      $400.00
# 2  PUBLIC TRANSPORTATION: From the house, quick p...      $395.00
# 3  There are buses that stop right in front of th...          NaN
# 4  From Logan Airport  and South Station you have...          NaN
#
#                                       xl_picture_url zipcode
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...   02131
# 1  https://a1.muscache.com/im/pictures/39327812/d...   02131
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...   02131
# 3  https://a2.muscache.com/im/pictures/39764190-1...     NaN
# 4  https://a1.muscache.com/im/pictures/97154760/8...   02131
#
# [5 rows x 95 columns]
#          id                                        picture_url  \
# 0  12147973  https://a2.muscache.com/im/pictures/c0842db1-e...
# 1   3075044  https://a1.muscache.com/im/pictures/39327812/d...
# 2      6976  https://a2.muscache.com/im/pictures/6ae8335d-9...
# 3   1436513  https://a2.muscache.com/im/pictures/39764190-1...
# 4   7651065  https://a1.muscache.com/im/pictures/97154760/8...
#
#                                       xl_picture_url   host_id host_name  \
# 0  https://a2.muscache.com/im/pictures/c0842db1-e...  31303940  Virginia
# 1  https://a1.muscache.com/im/pictures/39327812/d...   2572247    Andrea
# 2  https://a2.muscache.com/im/pictures/6ae8335d-9...     16701      Phil
# 3  https://a2.muscache.com/im/pictures/39764190-1...   6031442    Meghna
# 4  https://a1.muscache.com/im/pictures/97154760/8...  15396970     Linda
#
#   host_response_rate host_acceptance_rate  host_total_listings_count  \
# 0                NaN                  NaN                        1.0
# 1               100%                 100%                        1.0
# 2               100%                  88%                        1.0
# 3               100%                  50%                        1.0
# 4               100%                 100%                        1.0
#
#   neighbourhood_cleansed    city        ...            price  \
# 0             Roslindale  Boston        ...          $250.00
# 1             Roslindale  Boston        ...           $65.00
# 2             Roslindale  Boston        ...           $65.00
# 3             Roslindale  Boston        ...           $75.00
# 4             Roslindale  Boston        ...           $79.00
#
#   cancellation_policy weekly_price  monthly_price  security_deposit  \
# 0            moderate          NaN            NaN               NaN
# 1            moderate      $400.00            NaN            $95.00
# 2            moderate      $395.00      $1,350.00               NaN
# 3            moderate          NaN            NaN           $100.00
# 4            flexible          NaN            NaN               NaN
#
#   cleaning_fee number_of_reviews  review_scores_rating  instant_bookable  \
# 0       $35.00                 0                   NaN                 f
# 1       $10.00                36                  94.0                 t
# 2          NaN                41                  98.0                 f
# 3       $50.00                 1                 100.0                 f
# 4       $15.00                29                  99.0                 f
#
#    reviews_per_month
# 0                NaN
# 1               1.30
# 2               0.47
# 3               1.00
# 4               2.25
#
# [5 rows x 31 columns]

# %%
df_new1.shape
# fill 0  with no data

df_new1.id.fillna(0, inplace=True)

df_new1.reviews_per_month.fillna(0, inplace=True)
df_new1.instant_bookable.fillna('f', inplace=True)
df_new1.review_scores_rating.fillna(0, inplace=True)

df_new1.number_of_reviews.fillna(0, inplace=True)
df_new1.cleaning_fee.fillna(0, inplace=True)
df_new1.security_deposit.fillna(0, inplace=True)
df_new1.monthly_price.fillna(0, inplace=True)
#df_new1.amenities.fillna('na', inplace=True)
df_new1.amenities.fillna(0, inplace=True)
df_new1.price.fillna(0, inplace=True)

df_new1.weekly_price.fillna(0, inplace=True)
df_new1.beds.fillna(0, inplace=True)
df_new1.bathrooms.fillna(0, inplace=True)
df_new1.accommodates.fillna(0, inplace=True)
df_new1.room_type.fillna(0, inplace=True)
df_new1.property_type.fillna(0, inplace=True)
df_new1.longitude.fillna(0, inplace=True)
df_new1.latitude.fillna(0, inplace=True)
df_new1.country.fillna(0, inplace=True)
df_new1.zipcode.fillna(0, inplace=True)
df_new1.state.fillna(0, inplace=True)
df_new1.city.fillna(0, inplace=True)
df_new1.neighbourhood_cleansed.fillna(0, inplace=True)
df_new1.host_total_listings_count.fillna(0, inplace=True)
df_new1.host_acceptance_rate.fillna(0, inplace=True)
df_new1.host_response_rate.fillna(0, inplace=True)
df_new1.host_name.fillna(0, inplace=True)
df_new1.host_id.fillna(0, inplace=True)
df_new1.xl_picture_url.fillna(0, inplace=True)
df_new1.picture_url.fillna(0, inplace=True)
df_new1.shape
#remove rows with 0 values


#df_new1.to_csv('Clean.csv', index=False)
df_new1.shape
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:3660: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._update_inplace(new_data)
# (15191, 31)

# %%
df_new1 = df_new1[df_new1.id != 0]  #remove  rows with no id
df_new1 = df_new1[df_new1.price != 0] # remove rows with no price for venue
df_new1 = df_new1[df_new1.longitude != 0] # remove rows with no latitude for venue
df_new1 = df_new1[df_new1.latitude != 0] # remove rows with no longitude for venue
df_new1 = df_new1[df_new1.zipcode != 0] # remove rows with no longitude for venue
df_new1 = df_new1[df_new1.state != 0] # remove rows with no longitude for venue
df_new1 = df_new1[df_new1.city != 0] # remove rows with no longitude for venue
df_new1 = df_new1[df_new1.host_name != 0] # remove rows with no longitude for venue
df_new1 = df_new1[df_new1.host_id != 0] # remove rows with no longitude for venue

#df_new1.host_id.shape

print(df_new1.shape)

df_new1.to_csv("clean.csv", index=None)

print("csv created")
# Out:
# (15036, 31)
# csv created
